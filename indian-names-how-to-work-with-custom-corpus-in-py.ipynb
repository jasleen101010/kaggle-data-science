# %% [markdown]
# <a href="https://www.kaggle.com/code/jasleensondhi/indian-names-how-to-work-with-custom-corpus-in-py?scriptVersionId=121981037" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # How to import a custom corpus in Python?

# %% [markdown]
# **Importing a word list file**
#
# #loading libraries
# import nltk.data
#
# nltk.data.load('corpora/Indian/first_name.txt', format ='raw')

# %% [markdown]
# Useful link- https://python.plainenglish.io/creating-a-custom-corpus-928789c089e7

# %%
# opening the file in read mode
my_file = open("/kaggle/input/indian-names-corpus-nltk-data/Indian Names/first_name.txt", "r", encoding="utf8")
# reading the file
data = my_file.read()
  
# replacing end of line('/n') with ' ' and
# splitting the text it further when '.' is seen.
data_into_list = data.split("\n")
  
# printing the data
print(data_into_list)
my_file.close()
# Out:
# ['Aachal', 'Aadharsh', 'Aadhavi', 'Aadhira', 'Aadidev', 'Aadil', 'Aadita', 'Aaditya', 'Aaditya', 'Aadiv', 'Aadrik', 'Aagney', 'Aahan', 'Aahana', 'Aakaar', 'Aakanksha', 'Aakarsh', 'Aakash', 'Aakesh', 'Aakriti', 'Aakshi', 'Aamra', 'Aanchal', 'Aanya', 'Aarav', 'Aarav', 'Aariz', 'Aarjay', 'Aarna', 'Aarush', 'Aarushi', 'Aarvi', 'Aarya', 'Aaryan', 'Aashish', 'Aashvi', 'Aashvi', 'Aasim', 'Aastha', 'Aatish', 'Aatreya', 'Aayansh', 'Aayod', 'Aayush', 'Aayushi', 'Abbas', 'Abdul', 'Abdur', 'Abeer', 'Abhay', 'Abhaya', 'Abhaysinha', 'Abhedhya', 'Abhigya', 'Abhijeet', 'Abhijit', 'Abhijoy', 'Abhik', 'Abhilash', 'Abhilasha', 'Abhimanyu', 'Abhinandan', 'Abhinav', 'Abhishek', 'Abhisikta', 'Abhisumat', 'Abhitha', 'Abhoy', 'Abhyuday', 'Abinash', 'Abrar', 'Abuzar', 'Acchutan', 'Achintya', 'Achyut', 'Adarsh', 'Adhiraj', 'Adhrit', 'Adhyan', 'Adhyantika', 'Adil', 'Aditi', 'Adity', 'Aditya', 'Advaita', 'Advaith', 'Advika', 'Advith', 'Adweta', 'Adya', 'Aeman', 'Afzan', 'Agampreet', 'Agrim', 'Ahad', 'Ahilan', '
# ...

# %%
# opening the file in read mode
my_file = open("/kaggle/input/indian-names-corpus-nltk-data/Indian Names/last_name.txt", "r")
# reading the file
data = my_file.read()
  
# replacing end of line('/n') with ' ' and
# splitting the text it further when '.' is seen.
data_into_list = data.split("\n")
  
# printing the data
print(data_into_list)
my_file.close()
# Out:
# ['Acharya', 'Adhaulia', 'Adhya', 'Aenugu', 'Afreen', 'Afsar', 'Aftab', 'Agarawal', 'Agarwal', 'Agate', 'Aggarwal', 'Aggrawal', 'Agrahari', 'Agrawal', 'Ahamad', 'Ahluwalia', 'Ahmad', 'Ahmed', 'Ahuja', 'Aishwary', 'Akhtar', 'Akolkar', 'Alam', 'Aleem', 'Ali', 'Alwadhi', 'Amble', 'Anam', 'Anand', 'Andra', 'Anjum', 'Anne', 'Ansari', 'Anupama', 'Anwar', 'Apte', 'Arif', 'Arora', 'Arya', 'Ashraf', 'Asija', 'Asthana', 'Ataher', 'Athar', 'Atri', 'Attraa', 'Atwal', 'Aurora', 'Awasthi', 'Azam', 'Azhar', 'Azmi', 'Babu', 'Badal', 'Badami', 'Baddur', 'Baghel', 'Bahl', 'Bahri', 'Bai', 'Bail', 'Bains', 'Bais', 'Baiswar', 'Bajaj', 'Bajpai', 'Bajwa', 'Bakshi', 'Bal', 'Bala', 'Balakrishnan', 'Balan', 'Balasubramanian', 'Balay', 'Bali', 'Baliga', 'Balkoty', 'Balmiki', 'Balot', 'Bandi', 'Banerjee', 'Banik', 'Bano', 'Banothu', 'Bansal', 'Bapat', 'Bapna', 'Barad', 'Barai', 'Baral', 'Baranwal', 'Baria', 'Barman', 'Barnawal', 'Barnwal', 'Basak', 'Bassi', 'Basu', 'Bath', 'Batra', 'Batta', 'Bauri', 'Bava', 'Baw
# ...
